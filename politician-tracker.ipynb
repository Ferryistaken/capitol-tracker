# %% [markdown]
# # US Politician Quant Fund

# %%
# install.packages("jsonlite")

# %%
library("dplyr")
library("jsonlite")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
json <- as.data.frame(jsonlite::fromJSON("https://house-stock-watcher-data.s3-us-west-2.amazonaws.com/data/all_transactions.json"))

# %%
json
# Out:
#       disclosure_year disclosure_date transaction_date owner ticker
# 1     2021            10/04/2021      2021-09-27       joint BP
# 2     2021            10/04/2021      2021-09-13       joint XOM
# 3     2021            10/04/2021      2021-09-10       joint ILPT
# 4     2021            10/04/2021      2021-09-28       joint PM
# 5     2021            10/04/2021      2021-09-17       self  BLK
# 6     2021            12/01/2021      2021-12-01       joint AXP
# 7     2021            12/01/2021      2021-11-30       NA    KPLTW
# 8     2021            12/01/2021      2021-11-18       NA    AMD
# 9     2021            12/01/2021      2021-11-18       NA    AAPL
# 10    2021            12/01/2021      2021-11-24       NA    MSFT
# 11    2021            12/01/2021      2021-11-24       NA    MS
# 12    2021            12/01/2021      2021-11-16       NA    NEE
# 13    2021            12/01/2021      2021-11-16       NA    SLVM
# ...

# %%
selected_rep <- "Hon. Nancy Pelosi"

# %%
rep_df <- filter(json, representative %in% selected_rep)

rep_df <- rep_df[rev(order(as.Date(rep_df$disclosure_date, format="%m/%d/%Y"))), ]

rownames(rep_df) <- se
# Out:
#    disclosure_year disclosure_date transaction_date owner ticker
# 25 2022            03/21/2022      2022-03-17       self  TSLA
# 49 2022            02/28/2022      2022-01-21       self  DIS
# 48 2022            02/28/2022      2022-01-21       self  PYPL
# 47 2022            02/28/2022      2022-01-21       self  AAPL
# 46 2022            02/28/2022      2022-01-21       self  AXP
# 45 2022            02/28/2022      2022-01-27       self  AB
# 31 2022            01/12/2022      2021-12-30       self  AAPL
# 30 2022            01/12/2022      2021-12-30       self  AAPL
# 38 2021            12/29/2021      2021-12-17       self  DIS
# 37 2021            12/29/2021      2021-12-20       self  CRM
# 36 2021            12/29/2021      2021-12-20       self  CRM
# 35 2021            12/29/2021      2021-12-20       self  RBLX
# 34 2021            12/29/2021      2021-12-22       self  --
# 33 2021            12/29/2021      2021-12-21       self  MU
# ...
